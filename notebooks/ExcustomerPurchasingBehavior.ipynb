# %% [markdown]
# > # Exploration of customer purchasing behavior

# %%
import pandas as pd # type: ignore
import os
os.chdir('..')

# %%
store_path = './data/store.csv'
train_path = './data/test.csv'
test_path = './data/train.csv'

# %% [markdown]
# >> ### Load data

# %%
from scripts.ExcustomerPurchasingBehavior import load_data
train, test, store = load_data(train_path, test_path, store_path)
# Out:
# /home/naol/10-Acadamey/week-4/forecast-sales-for-rossmann-store/scripts/ExcustomerPurchasingBehavior.py:15: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv(test_path)

# %%
train.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
test.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %% [markdown]
# >> ### Check Missing Value

# %%
from scripts.ExcustomerPurchasingBehavior import check_missing_data
check_missing_data(test)
# Out:
# Series([], dtype: int64)

# %%
check_missing_data(train)
# Out:
# Open    11
# dtype: int64

# %%
train[train['Open'].isnull()]
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 479      480    622          4  2015-09-17   NaN      1            0
# 1335    1336    622          3  2015-09-16   NaN      1            0
# 2191    2192    622          2  2015-09-15   NaN      1            0
# 3047    3048    622          1  2015-09-14   NaN      1            0
# 4759    4760    622          6  2015-09-12   NaN      0            0
# 5615    5616    622          5  2015-09-11   NaN      0            0
# 6471    6472    622          4  2015-09-10   NaN      0            0
# 7327    7328    622          3  2015-09-09   NaN      0            0
# 8183    8184    622          2  2015-09-08   NaN      0            0
# 9039    9040    622          1  2015-09-07   NaN      0            0
# 10751  10752    622          6  2015-09-05   NaN      0            0
#
#        SchoolHoliday
# 479                0
# 1335               0
# 2191               0
# 3047               0
# 4759               0
# 5615               0
# 6471               0
# 7327               0
# 8183               0
# 9039               0
# 10751              0

# %%
check_missing_data(store)
# Out:
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %% [markdown]
# >> ### Handle missing Value

# %% [markdown]
# >> ### merge train and test data woth store

# %%
from scripts.ExcustomerPurchasingBehavior import merge_data
trian_merged, test_merged = merge_data(train, test, store)
